# %% [markdown]
# <a href="https://colab.research.google.com/github/NileshPatil24-a/Deep_Learning/blob/main/Neural_network_backword_propogation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# !git clone https://github.com/NileshPatil24-a/Deep_Learning.git
# Out:
# Cloning into 'Deep_Learning'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# %cd Deep_Learning
# Out:
# /content/Deep_Learning

# %%
ls
# Out:
# Neural_network_backword_propogation.ipynb  README.md

# %%
cd Neural_network_backword_propogation.ipynb
# Out:
# [Errno 20] Not a directory: 'Neural_network_backword_propogation.ipynb'
# /content/Deep_Learning
